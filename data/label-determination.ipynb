# %% [markdown]
# # Load some libraries and the `read_pcap` function.

# %%
from tqdm import tqdm
import scapy
from scapy.utils import RawPcapReader, RawPcapNgReader
import pandas as pd
from pathlib import Path

assert scapy.__version__ == '2.4.4'  # pip install scapy==2.4.4


def read_pcap(path: str or Path) -> pd.DataFrame:
    path = Path(path)
    assert path.exists(), 'File not found.'

    signature = path.read_bytes()[:4]
    if signature == b'\x4D\x3C\xB2\xA1':
        Reader = RawPcapReader
        unit = 'ns'  # the second timestamp field represents a nanosecond.
        columns = ['sec', unit, 'wirelen', 'caplen', 'payload']
    elif signature == b'\xD4\xC3\xB2\xA1':
        Reader = RawPcapReader
        unit = 'us'  # the second timestamp field represents a microsecond.
        columns = ['sec', unit, 'wirelen', 'caplen', 'payload']
    elif signature == b'\n\r\r\n':
        Reader = RawPcapNgReader
        columns = ['linktype', 'tsresol', 'tshigh', 'tslow', 'wirelen', 'payload']
    else:
        raise ValueError(f'The {signature=} is an unknown signature.')

    with path.open('rb') as fp:
        reader = Reader(fp)
        iterator = tqdm(reader, desc=f'Parsing {path}')
        list_output = list()
        for payload, metadata in iterator:
            list_output.append(tuple(metadata) + (payload,))

    df = pd.DataFrame(list_output, columns=columns)
    if Reader == RawPcapReader:
        df['timestamp'] = pd.to_datetime(df['sec'], unit='s')
        df['timestamp'] += pd.to_timedelta(df[unit], unit=unit)  # absolute time
    elif Reader == RawPcapNgReader:
        df['timestamp'] = pd.to_datetime(((df['tshigh'].values << 32) + df['tslow']) * 1e-9, unit='s') # absolute time
    df['time'] = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()  # relative time
    return df[['time', 'timestamp', 'payload']].copy()

# %% [markdown]
# # the 36 packets that the adversary have injected repeatedly.

# %%
df_injected = read_pcap('single-MPEG-frame.pcap')
df_injected
# Out:
# Parsing single-MPEG-frame.pcap: 36it [00:00, 191132.84it/s]
#         time                     timestamp
# 0   0.000000 2019-06-11 10:51:55.538378650  \
# 1   0.000037 2019-06-11 10:51:55.538415200
# 2   0.000130 2019-06-11 10:51:55.538508650
# 3   0.000246 2019-06-11 10:51:55.538624900
# 4   0.000378 2019-06-11 10:51:55.538756950
# 5   0.000515 2019-06-11 10:51:55.538893300
# 6   0.001003 2019-06-11 10:51:55.539381700
# 7   0.001040 2019-06-11 10:51:55.539418400
# 8   0.001133 2019-06-11 10:51:55.539511450
# 9   0.003998 2019-06-11 10:51:55.542376300
# 10  0.004034 2019-06-11 10:51:55.542412950
# 11  0.004134 2019-06-11 10:51:55.542512500
# 12  0.004256 2019-06-11 10:51:55.542635100
# 13  0.004997 2019-06-11 10:51:55.543375200
# 14  0.005033 2019-06-11 10:51:55.543411850
# 15  0.005128 2019-06-11 10:51:55.543506500
# 16  0.005246 2019-06-11 10:51:55.543624300
# 17  0.005372 2019-06-11 10:51:55.543750700
# 18  0.005995 2019-06-11 10:51:55.544374100
# 19  0.006032 2019-06-11 10:51:55.544410700
# 20  0.006133 2019-06-11 10:51:55.544512100
# 21  0.006253 2019-06-11 10:51:55.544632100
# 22  0.006376 2019-06-11 10:51:55.544754300
# 23  0.006500 2019-06-11 10:51:55.544878300
# 24  0.006629 2019-06-11 10:51:55.545007300
# 25  0.006999 2019-06-11 10:51:55.545377350
# 26  0.008258 2019-06-11 10:51:55.546636900
# 27  0.009999 2019-06-11 10:51:55.548377700
# 28  0.010036 2019-06-11 10:51:55.548414300
# 29  0.010143 2019-06-11 10:51:55.548522150
# 30  0.010254 2019-06-11 10:51:55.548632250
# 31  0.012008 2019-06-11 10:51:55.550386150
# 32  0.012044 2019-06-11 10:51:55.550422800
# 33  0.012136 2019-06-11 10:51:55.550514700
# 34  0.012253 2019-06-11 10:51:55.550631300
# 35  0.012376 2019-06-11 10:51:55.550754550
#
#                                               payload
# 0   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 1   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 2   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 3   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 4   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 5   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 6   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 7   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 8   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 9   b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 10  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 11  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 12  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 13  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 14  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 15  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 16  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 17  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 18  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 19  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 20  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 21  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 22  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 23  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 24  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 25  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 26  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 27  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 28  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 29  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 30  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 31  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 32  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 33  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 34  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...
# 35  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...

# %% [markdown]
# # load all packet dumps

# %%
files = [
    'driving_01_injected.pcap',
    'driving_01_original.pcap',
    'driving_02_injected.pcap',
    'driving_02_original.pcap',
    'indoors_01_injected.pcap',
    'indoors_01_original.pcap',
    'indoors_02_injected.pcap',
    'indoors_02_original.pcap'
]

dict_df = dict()
for file in files:
    dict_df[file] = read_pcap(file)
# Out:
# Parsing driving_01_injected.pcap: 1007624it [00:01, 566664.13it/s]
# Parsing driving_01_original.pcap: 808135it [00:00, 943437.11it/s]
# Parsing driving_02_injected.pcap: 934084it [00:01, 575352.74it/s]
# Parsing driving_02_original.pcap: 757688it [00:00, 954913.99it/s]
# Parsing indoors_01_injected.pcap: 219780it [00:00, 585257.29it/s]
# Parsing indoors_01_original.pcap: 153799it [00:00, 941767.65it/s]
# Parsing indoors_02_injected.pcap: 463320it [00:00, 571997.85it/s]
# Parsing indoors_02_original.pcap: 332419it [00:00, 942834.40it/s]

# %% [markdown]
# # label determination.
#
# check whether each packet is one of the 36 packets. If so, the packet was injected (label `1`). If not, the packet was benign (label `0`) and the packet must be in a corresponding packet dump (*_original.pcap)

# %%
for file in files:
    df = dict_df[file]
    df['label'] = df['payload'].isin(df_injected['payload']).astype('int')
    print('file: {} / Label count: {}'.format(file, df['label'].value_counts().to_dict()))
# Out:
# file: driving_01_injected.pcap / Label count: {0: 807968, 1: 199656}
# file: driving_01_original.pcap / Label count: {0: 808135}
# file: driving_02_injected.pcap / Label count: {0: 757504, 1: 176580}
# file: driving_02_original.pcap / Label count: {0: 757688}
# file: indoors_01_injected.pcap / Label count: {0: 153792, 1: 65988}
# file: indoors_01_original.pcap / Label count: {0: 153799}
# file: indoors_02_injected.pcap / Label count: {0: 332414, 1: 130906}
# file: indoors_02_original.pcap / Label count: {0: 332419}

# %% [markdown]
# print out some benign and injected packets.

# %%
dict_df['indoors_01_injected.pcap'].loc[25010: 25030]
# Out:
#              time                     timestamp
# 25010  120.313818 2020-03-19 03:15:50.741228032  \
# 25011  120.313845 2020-03-19 03:15:50.741254400
# 25012  120.313935 2020-03-19 03:15:50.741344768
# 25013  120.314049 2020-03-19 03:15:50.741458176
# 25014  120.314173 2020-03-19 03:15:50.741583104
# 25015  120.314298 2020-03-19 03:15:50.741707264
# 25016  120.314424 2020-03-19 03:15:50.741833728
# 25017  120.314548 2020-03-19 03:15:50.741958144
# 25018  120.314678 2020-03-19 03:15:50.742087168
# 25019  120.333835 2020-03-19 03:15:50.761244416
# 25020  120.334588 2020-03-19 03:15:50.761998080
# 25021  120.335583 2020-03-19 03:15:50.762992384
# 25022  120.336584 2020-03-19 03:15:50.763993344
# 25023  120.337637 2020-03-19 03:15:50.765046272
# 25024  120.338631 2020-03-19 03:15:50.766040320
# 25025  120.339585 2020-03-19 03:15:50.766994688
# 25026  120.340582 2020-03-19 03:15:50.767991552
# 25027  120.341586 2020-03-19 03:15:50.768995328
# 25028  120.341810 2020-03-19 03:15:50.769219584
# 25029  120.341836 2020-03-19 03:15:50.769245440
# 25030  120.341935 2020-03-19 03:15:50.769344768
#
#                                                  payload  label
# 25010  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25011  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25012  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25013  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25014  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25015  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25016  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25017  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25018  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25019  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25020  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25021  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25022  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25023  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25024  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25025  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25026  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25027  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      1
# 25028  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25029  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
# 25030  b'\x91\xe0\xf0\x00\xfe\x82\x00\xfcp\x00\x00\x0...      0
